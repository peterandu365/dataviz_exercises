# %% [markdown]
# ## Matplotlib Assignment

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity =  "all"

# %%
# import pandas
import pandas as pd

# import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('company_sales_data.csv')

# %%
df.head()

# %% [markdown]
# ### Task 1: Read the `total_profit` of all months and display it using a line plot.

# %%
# plot the total_profit of all months and get a line plot

plt.plot(df['month_number'],df['total_profit'],label='Profit data of last year')

# %%
df.plot(x='month_number',y='total_profit',kind='line',label='Profit data of last year')
# Out:
# <AxesSubplot: xlabel='month_number'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.lineplot(df['month_number'],df['total_profit'],label='Profit data of last year')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'lineplot'

# %% [markdown]
# ### Task 2: Read all the different product sales data and display it using a multiline plot.

# %%
# Read all the different product sales data and display it using a multiline plot:

plt.plot(df['month_number'],df['facecream'],label='Facecream Sales Data',marker='o',linestyle='--')
plt.plot(df['month_number'],df['facewash'],label='Facewash Sales Data',marker='o',linestyle='--')
plt.plot(df['month_number'],df['toothpaste'],label='Toothpaste Sales Data',marker='o',linestyle='--')
plt.plot(df['month_number'],df['bathingsoap'],label='Bathingsoap Sales Data',marker='o',linestyle='--')
plt.plot(df['month_number'],df['shampoo'],label='Shampoo Sales Data',marker='o',linestyle='--')
plt.plot(df['month_number'],df['moisturizer'],label='Moisturizer Sales Data',marker='o',linestyle='--')
plt.show()

# %% [markdown]
# ### Task 3: Read the `total_profit` of each month and display it using a histogram to find out which profit ranges are the most common.

# %%
df.total_profit.plot(kind='hist',bins=5)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 dots = sns.load_dataset("dots")
#       2 sns.relplot(
#       3     data=dots, kind="line",
#       4     x="time", y="firing_rate", col="align",
#       5     hue="choice", size="coherence", style="choice",
#       6     facet_kws=dict(sharex=False),
#       7 )
#
# NameError: name 'sns' is not defined
